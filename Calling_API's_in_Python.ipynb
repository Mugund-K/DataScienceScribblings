# %% [markdown]
# <a href="https://colab.research.google.com/github/Mugund-K/DataScienceScribblings/blob/main/Calling_API's_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
#  'patch',
#  'post',
#  'put',
#  'request',
#  'session',
# ...

# %%
response = requests.get("https://api.yelp.com/v3/businesses/search")
print(response)
# Out:
# <Response [400]>

# %%
response
# Out:
# <Response [400]>

# %%
url = "https://api.yelp.com/v3/businesses/search"
api_key = "NhS50GhtIO-suqxSPq3w96ntUfbNJ352HMp52PClEEZj49nug9FvtYYCwcxlXgYNeG_qcLasJOJkvTD8wsFwnvxhQDvzGFeG7OeziJVOxxbPDpwtt4-0TzcQkkYiYHYx"
headers = {
    "Authorization": "Bearer " + api_key
}
params = {
    "term": "Barber",
    "location": "NYC"
}
response = requests.get(url, headers = headers, params=params)

# %%
response.text
# Out:
# '{"businesses": [{"id": "UywFXTRiPkuJZTuoJDg4yw", "alias": "ace-of-cuts-barber-shop-new-york", "name": "Ace of Cuts Barber Shop", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/JvP3alqrvkiH-1iQqVkdjQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ace-of-cuts-barber-shop-new-york?adjust_creative=oVXPGieKF8V7jsqhcMnr_g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=oVXPGieKF8V7jsqhcMnr_g", "review_count": 454, "categories": [{"alias": "barbers", "title": "Barbers"}, {"alias": "menshair", "title": "Men\'s Hair Salons"}], "rating": 4.5, "coordinates": {"latitude": 40.725089619932, "longitude": -73.983141054002}, "transactions": [], "price": "$", "location": {"address1": "518 E 6th St", "address2": null, "address3": "", "city": "New York", "zip_code": "10009", "country": "US", "state": "NY", "display_address": ["518 E 6th St", "New York, NY 10009"]}, "phone": "+16467073507", "display_phone": "(646) 707-3507", "distance": 2378.029945802448}, {"id
# ...

# %%
result = response.json()["businesses"]

# %%
result
# Out:
# [{'alias': 'ace-of-cuts-barber-shop-new-york',
#   'categories': [{'alias': 'barbers', 'title': 'Barbers'},
#    {'alias': 'menshair', 'title': "Men's Hair Salons"}],
#   'coordinates': {'latitude': 40.725089619932, 'longitude': -73.983141054002},
#   'display_phone': '(646) 707-3507',
#   'distance': 2378.029945802448,
#   'id': 'UywFXTRiPkuJZTuoJDg4yw',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JvP3alqrvkiH-1iQqVkdjQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '518 E 6th St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'country': 'US',
#    'display_address': ['518 E 6th St', 'New York, NY 10009'],
#    'state': 'NY',
#    'zip_code': '10009'},
#   'name': 'Ace of Cuts Barber Shop',
#   'phone': '+16467073507',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 454,
#   'transactions': [],
# ...

# %%
for business in result:
  if(business["rating"] > 4.5):
    print(business["name"])
# Out:
# 12 Pell
# Bonefade Barbers
# The Kinsman Barber Shop
# Gentlemen's Barbershop
# Next Level Barber Shop
# Barbers Point
# Hairitage Barber Company
# Clipper Mobile
# The Flying Row
